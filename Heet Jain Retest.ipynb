# %%
import pandas as pd

# %%
olympic = pd.read_csv("athlete_events.csv")
olympic
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
london_city = olympic.loc[(olympic["City"] == "London")&(olympic["Games"] == "2012 Summer")]
london_city
# Out:
#             ID                                     Name Sex   Age  Height  \
# 1            2                                 A Lamusi   M  23.0   170.0
# 98          34       Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0
# 134         48                         Abdelhak Aatakni   M  24.0     NaN
# 164         67  Mariya Vasilyevna Abakumova (-Tarabina)   F  26.0   179.0
# 174         73                                Luc Abalo   M  27.0   182.0
# ...        ...                                      ...  ..   ...     ...
# 271020  135526                             Dniel Zwickl   M  27.0   178.0
# 271023  135528                            Marc Zwiebler   M  28.0   181.0
# 271052  135547            Viktoriya Viktorovna Zyabkina   F  19.0   174.0
# 271090  135557                             Dominik ycki   M  38.0   192.0
# 271091  135558                       ukasz Tomasz ygado   M  32.0   200.0
#
#         Weight        Team  NOC        Games  Year  Season    City  \
# ...

# %%
london_city = london_city["ID"].unique()
len(london_city)
# Out:
# 10517

# %%
female =olympic.loc[(olympic["City"] == "Beijing")&(olympic["Games"] == "2008 Summer") & (olympic["Sex"] == "F")]
female
# Out:
#             ID                                       Name Sex   Age  Height  \
# 79          21                  Ragnhild Margrethe Aamodt   F  27.0   163.0
# 136         49                               Moonika Aava   F  28.0   168.0
# 163         67    Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0
# 167         69                          Tamara Abalde Daz   F  19.0   185.0
# 281        148                     Kathryn "Katie" Abbott   F  21.0   164.0
# ...        ...                                        ...  ..   ...     ...
# 270936  135489      Anastasiya Valeryevna Zuyeva-Fesikova   F  18.0   182.0
# 270937  135489      Anastasiya Valeryevna Zuyeva-Fesikova   F  18.0   182.0
# 270972  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  47.0   183.0
# 270986  135508                   Vera Igorevna Zvonaryova   F  23.0   172.0
# 270987  135508                   Vera Igorevna Zvonaryova   F  23.0   172.0
#
# ...

# %%
female_df = female["ID"].unique()
len(female_df)
# Out:
# 4609

# %%
male = olympic.loc[(olympic["City"] == "Beijing")&(olympic["Games"] == "2008 Summer") & (olympic["Sex"] == "M")]
male
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 159         63               Jos Luis Abajo Gmez   M  30.0   194.0    87.0
# 172         72  Aleksey Aleksandrovich Abalmasov   M  28.0   180.0    83.0
# 173         73                         Luc Abalo   M  23.0   182.0    86.0
# 198         92                     Ignazio Abate   M  21.0   180.0    73.0
# 200         93                    Jol Marc Abati   M  38.0   190.0    85.0
# ...        ...                               ...  ..   ...     ...     ...
# 270852  135458                          Rami Zur   M  31.0   175.0    77.0
# 270932  135486          Viktor Valeryevich Zuyev   M  25.0   188.0    91.0
# 271022  135528                     Marc Zwiebler   M  24.0   181.0    75.0
# 271026  135530                    Philip Zwiener   M  23.0   202.0    98.0
# 271089  135557                      Dominik ycki   M  34.0   192.0    95.0
#
# ...

# %%
male_df = male["ID"].unique()
len(male_df)
# Out:
# 6290

# %%
olympic = olympic.sort_values("Medal" , ascending = True)
athelete.head(10)
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 104480   52875       Yevgeniya Andreyevna Ivanova   F  29.0   176.0    68.0
# 236585  118617  Matthew Stephen C. "Matt" Targett   M  26.0   198.0    90.0
# 112610   57039                     Wandee Kameaim   F  26.0   150.0    58.0
# 112604   57035                   Reneta Kamberova   F  25.0   170.0    53.0
# 112580   57018                      Mitsuo Kamata   M  30.0   177.0    67.0
# 112561   57005                 Kunishige Kamamoto   M  24.0   179.0    74.0
# 112535   56992       Lesia Mykhailivna Kalytovska   F  20.0   174.0    68.0
# 112675   57078     Eleonora Kaminskait (Ruokien-)   F  25.0   178.0    70.0
# 112518   56979         Henry Gustaves Kaltenbrunn   M  22.0     NaN     NaN
# 112460   56948          Margit Kalocsai (Krammer)   F  26.0     NaN     NaN
#
#                 Team  NOC        Games  Year  Season            City  \
# ...
